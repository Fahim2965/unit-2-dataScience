# %% [markdown]
# # Lesson 1
# This my first project in data analytics.

# %%
print('hola mundo')
# Out:
# hola mundo

# %%
import matplotlib.pyplot as plt

y = [1, 2, 3, 4]
x = [22, 87, 0, 18]

plt.plot(x, y)

plt.ylabel('Memes')
plt.xlabel('Ok')
plt.title('Big man tings')
# Out:
# Text(0.5, 1.0, 'Big man tings')

# %%
number = ['five','four', 'three', 'two', 'one']
counts = [40, 100, 30, 55, 90]

plt.bar(number, counts)
# Out:
# <BarContainer object of 5 artists>

# %%
p = [18, 20, 25, 37, 12]

plt.pie(p)
# Out:
# ([<matplotlib.patches.Wedge at 0x21f55529490>,
# ...
#  [Text(0.962745767658053, 0.5320907693772807, ''),
#   Text(6.735557395310444e-17, 1.1, ''),
#   Text(-1.0480526372291499, 0.33404441261159296, ''),
#   Text(-0.15376940262567598, -1.0891992337566818, ''),
#   Text(1.038271645116746, -0.3633070202274741, '')])
