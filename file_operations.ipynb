# %% [markdown]
# # File Operations
# In this excercise you will begin working on using the `open` function within python to manipulate files and create reports on those files.
#
# **YOU ARE TO INCLUDE COMMENTS ALONG SIDE YOUR CODE**

# %% [markdown]
# 1. Open the file "states.txt" that you downloaded, what does this file contain?
# ```
# Once I downloaded the states.txt file and opend it I saw the U.S. states listed multiple times.
# ```

# %% [markdown]
# *Use the code block below to open the same file, using a `for` loop print each line to the console.*

# %%
with open('states.txt') as list:
    for x in list:
        print(x)
# Out:
# WA
#
# MO
#
# KS
#
# SC
#
# GA
#
# FL
#
# MN
#
# NC
#
# HI
#
# CT
#
# TX
#
# MA
#
# OK
#
# IL
#
# HI
#
# CA
#
# TX
#
# WA
#
# OH
#
# PA
#
# MO
#
# IL
#
# CA
#
# IL
#
# CA
#
# DC
#
# FL
#
# NC
#
# NY
#
# VA
#
# TX
#
# CA
#
# DC
#
# TX
#
# OH
#
# WA
#
# FL
#
# MN
#
# DC
#
# FL
#
# CA
#
# FL
#
# TX
#
# CT
#
# NC
#
# MO
#
# TX
#
# MA
#
# TX
#
# WA
#
# IN
#
# IN
#
# MO
#
# AL
#
# OK
#
# GA
#
# NY
#
# IN
#
# OK
#
# IN
#
# CA
#
# GA
#
# CA
#
# CA
#
# IN
#
# NY
#
# MS
#
# CA
#
# NV
#
# ID
#
# MN
#
# VA
#
# WY
#
# WV
#
# MN
#
# MO
#
# TX
#
# MA
#
# IN
#
# IA
#
# WA
#
# MN
#
# CA
#
# NE
#
# IL
#
# IL
#
# PA
#
# GA
#
# TX
#
# OH
#
# DE
#
# TX
#
# NM
#
# TX
#
# MA
#
# LA
#
# GA
#
# TN
#
# CA
#
# DC
#
# FL
#
# CO
#
# MI
#
# MD
#
# FL
#
# FL
#
# NC
#
# OH
#
# IA
#
# NE
#
# TX
#
# IN
#
# TX
#
# CA
#
# TX
#
# IL
#
# CA
#
# VA
#
# TX
#
# CA
#
# NY
#
# IN
#
# NY
#
# OH
#
# NY
#
# TN
#
# DC
#
# CA
#
# MN
#
# VA
#
# UT
#
# NH
#
# TX
#
# CA
#
# PA
#
# CO
#
# TX
#
# FL
#
# CA
#
# PA
#
# OH
#
# MD
#
# CT
# ...

# %% [markdown]
# 2. What type of chart would be best to represent this data? Explain why
# ```
# The type of chart that would be best to represent this data is a bar graph becuase the would be all whole numbers.
# ```
# 3. How would we need to transform the data we have, to be displayed in this chart?
# ```
# We would need to count how many times a state repeats, narrowing it down to 50 states wit how many times each state was repeated.
# ```

# %% [markdown]
# Using your knowledge of Python and Matplotlib write your code to transform and graph the data below.
#
# After your code create a new Markdown block to describe your analysis

# %%
states = open('states.txt')
AL = 0
AK = 0
AZ = 0
AR = 0
AS = 0
CA = 0
CO = 0
CT = 0
DE = 0
DC = 0
FL = 0
GA = 0
HI = 0
ID = 0
IL = 0
IN = 0
IA = 0
KS = 0
KY = 0
LA = 0
ME = 0
MD = 0
MA = 0
MI = 0
MN = 0
MS = 0
MO = 0
MT = 0
NE = 0
NV = 0
NH = 0
NJ = 0
NM = 0
NY = 0
NC = 0
ND = 0
OH = 0
OK = 0
OR = 0
PA = 0
RI = 0
SC = 0
SD = 0
TN = 0
TX = 0
UT = 0
VT = 0
VA = 0
WA = 0
WV = 0
WI = 0
WY = 0

for x in states.readlines():
    if x == "AL\n":
        AL += 1
    if x == "AK\n":
        AK += 1
    if x == "AZ\n":
        AZ += 1
    if x == "AR\n":
        AR += 1
    if x == "CN\n":
        CA += 1
    if x == "CO\n":
        CO += 1
    if x == "CT\n":
        CT += 1
    if x == "DE\n":
        DE += 1
    if x == "DC\n":
        DC += 1
    if x == "FL\n":
        FL += 1
    if x == "GA\n":
        GA += 1
    if x == "HI\n":
        HI += 1
    if x == "ID\n":
        ID += 1
    if x == "IL\n":
        IL += 1
    if x == "IN\n":
        IN += 1
    if x == "IA\n":
        IA += 1
    if x == "KS\n":
        KS += 1
    if x == "KY\n":
        KY += 1
    if x == "LA\n":
        LA += 1
    if x == "ME\n":
        ME += 1
    if x == "MD\n":
        MD += 1
    if x == "MA\n":
        MA += 1
    if x == "MI\n":
        MI += 1
    if x == "MN\n":
        MN += 1
    if x == "MS\n":
        MS += 1
    if x == "MO\n":
        MO += 1
    if x == "MT\n":
        MT += 1
    if x == "NE\n":
        NE += 1
    if x == "NV\n":
        NV += 1
    if x == "NH\n":
        NH += 1
    if x == "NJ\n":
        NJ += 1
    if x == "NM\n":
        NM += 1
    if x == "NY\n":
        NY += 1
    if x == "NC\n":
        NC += 1
    if x == "ND\n":
        ND += 1
    if x == "OH\n":
        OH += 1
    if x == "OK\n":
        OK += 1
    if x == "OR\n":
        OR += 1
    if x == "PA\n":
        PA += 1
    if x == "RI\n":
        RI += 1
    if x == "SC\n":
        SC += 1
    if x == "SD\n":
        SD += 1
    if x == "TN\n":
        TN += 1
    if x == "TX\n":
        TX += 1
    if x == "UT\n":
        UT += 1
    if x == "VT\n":
        VT += 1
    if x == "VA\n":
        VA += 1
    if x == "WA\n":
        WA += 1
    if x == "WV\n":
        WV += 1
    if x == "WI\n":
        WI += 1
    if x == "WY\n":
        WY =+ 1
print()
import matplotlib.pyplot as plt

x = ['AL', 'AK', 'AZ', 'AR', 'AS', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']
y = [AL, AK, AZ, AR, AS, CA, CO, CT, DE, DC, FL, GA, HI, ID, IL, IN, IA, KS, KY, LA, ME, MD, MA, MI, MN, MS, MO, MT, NE, NV, NH, NJ, NM, NY, NC, ND, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VT, VA, WA, WV, WI, WY]

plt.bar(x, y)
# Out:
# <BarContainer object of 52 artists>

# %% [markdown]
# Once I ran the code I was ble to see the graph and how many times each state was writen in the state.txt file. I also noticed that the x-axis increments by 10 without me even telling it to. Also I see that the states are in the y-axis with space between each.
